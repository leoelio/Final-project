# %% [markdown]
# # MuJoCo Frozen CLIP Patch-Pointer Training
# Enable Internet so Kaggle can download the CLIP checkpoint, attach the exported dataset, then run the next cell.

# %%
# Frozen CLIP Patch-Pointer Training on Kaggle
from pathlib import Path
DATASET = Path('/kaggle/input/widowx-mujoco-patch-pointer-v1')
WORK = Path('/kaggle/working')
# !pip install -q transformers==4.57.0
# !cp {DATASET}/scripts/kaggle_train_patch_pointer.py {WORK}/kaggle_train_patch_pointer.py
# !python {WORK}/kaggle_train_patch_pointer.py --dataset-root {DATASET} --output {WORK}/clip_patch_pointer_kaggle_v1.pt --metrics {WORK}/clip_patch_pointer_kaggle_v1.json --epochs 300 --device cuda
print('Download clip_patch_pointer_kaggle_v1.pt and clip_patch_pointer_kaggle_v1.json, then run the local MuJoCo evaluator documented in KAGGLE_UPLOAD.md.')
